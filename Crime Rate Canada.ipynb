# %%
# %pip install requests
# Out:
# Python interpreter will be restarted.
# Requirement already satisfied: requests in /databricks/python3/lib/python3.9/site-packages (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.9/site-packages (from requests) (1.26.9)
# Python interpreter will be restarted.

# %%
import requests
from pyspark.sql import SparkSession
from io import BytesIO
from pyspark.sql import DataFrame
import pandas as pd

# Configurar la URL base para la API
base_url = "https://open.canada.ca/data/api/action/"

# Lista de datasets a descargar (nombre y ID)
datasets_to_download = [
    {"title": "Crime Statistics - Incidents and rates for selected offences", "id": "47466568-c38d-8bb9-26d9-331079dad727"}
]

def download_dataset_to_spark(dataset_id, title):
    endpoint = f"package_show?id={dataset_id}"
    response = requests.get(f"{base_url}{endpoint}")
    
    if response.status_code == 200:
        dataset_info = response.json()
        for resource in dataset_info['result']['resources']:
            if resource['format'].lower() == 'csv':
                csv_url = resource['url']
                csv_response = requests.get(csv_url)
                
                # Leer el CSV directamente en un DataFrame de pandas desde la respuesta
                csv_content = BytesIO(csv_response.content)
                df_pandas = pd.read_csv(csv_content, sep=';')  # Ajusta el separador si es necesario
                
                # Convertir el DataFrame de pandas a un DataFrame de Spark
                df_spark = spark.createDataFrame(df_pandas)
                
                # Mostrar algunos datos para verificar
                df_spark.show()
                
                # Guardar el DataFrame de Spark en DBFS (opcional)
                dbfs_path = f"/files/tables/{title.replace(' ', '_').lower()}.csv"
                df_spark.write.csv(dbfs_path, header=True)
                
                print(f"{title} descargado y cargado en Spark DataFrame")
                return df_spark
    else:
        print(f"Error al obtener el dataset {title}: {response.status_code}")

# Descargar y cargar el dataset en Databricks usando PySpark
for dataset in datasets_to_download:
    df_spark = download_dataset_to_spark(dataset['id'], dataset['title'])
# Out:
# +-----------------------------------------+
# |GEOGRAPHY,YEAR,VIOLATIONS,INCIDENTS,RATES|
# +-----------------------------------------+
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Amherst, Nova Sco...|
# +-----------------------------------------+
# only showing top 20 rows
#
# Crime Statistics - Incidents and rates for selected offences descargado y cargado en Spark DataFrame

# %%
df_spark.show()
# Out:
# +-----------------------------------------+
# |GEOGRAPHY,YEAR,VIOLATIONS,INCIDENTS,RATES|
# +-----------------------------------------+
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Nova Scotia [12],...|
# |                     Amherst, Nova Sco...|
# +-----------------------------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import split, col, expr, trim, concat_ws
from pyspark.sql.types import StructType, StructField, StringType

# Crear esquema y DataFrame inicial
schema = StructType([StructField("combined", StringType(), True)])
df = spark.createDataFrame(df_spark.rdd, schema)

# Mostrar los primeros registros
df.show(5, truncate=False)

# Dividir usando expresión regular, capturando comas fuera de quotes
df = df.withColumn("split_col", split(trim(col("combined")), r',(?=(?:[^"]*"[^"]*")*[^"]*$)'))

# Añadir columna para contar el número de elementos después de la separación
df = df.withColumn("num_cols", expr("size(split_col)"))

# Mostrar filas problemáticas que no tienen 5 columnas
df_invalid = df.filter(col("num_cols") != 5)
df_invalid.show(truncate=False)

# Filtrar las filas válidas que tienen exactamente 5 columnas
df_valid = df.filter(col("num_cols") == 5)

# Asignar columnas correctas para las filas válidas
df_valid = df_valid.withColumn("Geography", trim(col("split_col").getItem(0))) \
                   .withColumn("Year", trim(col("split_col").getItem(1))) \
                   .withColumn("Violations", trim(col("split_col").getItem(2))) \
                   .withColumn("Incidents", trim(col("split_col").getItem(3))) \
                   .withColumn("Rates", trim(col("split_col").getItem(4))) \
                   .drop("split_col", "combined", "num_cols")

# Mostrar las filas válidas
df_valid.show(5, truncate=False)

# Ajustar filas problemáticas para que tengan exactamente 5 elementos
# Aquí unimos los primeros elementos que corresponden a "Geography" y los demás campos
df_fixed = df_invalid.withColumn("Geography", concat_ws(", ", col("split_col").getItem(0), col("split_col").getItem(1), col("split_col").getItem(2))) \
                     .withColumn("Year", trim(col("split_col").getItem(3))) \
                     .withColumn("Violations", trim(col("split_col").getItem(4))) \
                     .withColumn("Incidents", trim(col("split_col").getItem(5))) \
                     .withColumn("Rates", trim(col("split_col").getItem(6))) \
                     .drop("split_col", "num_cols", "combined")

# Mostrar las filas ajustadas
df_fixed.show(5, truncate=False)

# Unir DataFrames válidos y corregidos manualmente
df_final = df_valid.unionByName(df_fixed)

# Verificar el esquema final y mostrar resultados
df_final.printSchema()
df_final.show(50, truncate=False)

# Mostrar valores únicos de Geography para confirmar que están completos y correctos
df_final.select("Geography").distinct().show(50, truncate=False)
df_final.show(50)
# Out:
# +-------------------------------------------------------------------------------------+
# |combined                                                                             |
# +-------------------------------------------------------------------------------------+
# |Nova Scotia [12],2010,Homicide [110],21,2.23                                         |
# |Nova Scotia [12],2010,Attempted murder [1210],24,2.55                                |
# |Nova Scotia [12],2010,"Sexual assault, level 3, aggravated [1310]",6,0.64            |
# |Nova Scotia [12],2010,"Sexual assault, level 2, weapon or bodily harm [1320]",13,1.38|
# |Nova Scotia [12],2010,"Sexual assault, level 1 [1330]",662,70.27                     |
# +-------------------------------------------------------------------------------------+
# only showing top 5 rows
#
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
# |combined                                                                                                                                               |split_col                                                                                                                                                      |num_cols|
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
# |Amherst, Nova Scotia, municipal [12001],2010,Homicide [110],1,10.14                                                                                    |[Amherst,  Nova Scotia,  municipal [12001], 2010, Homicide [110], 1, 10.14]                                                                                    |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,Attempted murder [1210],0,0                                                                               |[Amherst,  Nova Scotia,  municipal [12001], 2010, Attempted murder [1210], 0, 0]                                                                               |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,"Sexual assault, level 3, aggravated [1310]",0,0                                                          |[Amherst,  Nova Scotia,  municipal [12001], 2010, "Sexual assault, level 3, aggravated [1310]", 0, 0]                                                          |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,"Sexual assault, level 2, weapon or bodily harm [1320]",0,0                                               |[Amherst,  Nova Scotia,  municipal [12001], 2010, "Sexual assault, level 2, weapon or bodily harm [1320]", 0, 0]                                               |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,"Sexual assault, level 1 [1330]",8,81.15                                                                  |[Amherst,  Nova Scotia,  municipal [12001], 2010, "Sexual assault, level 1 [1330]", 8, 81.15]                                                                  |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,Total sexual violations against children [130],2,20.29                                                    |[Amherst,  Nova Scotia,  municipal [12001], 2010, Total sexual violations against children [130], 2, 20.29]                                                    |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,"Assault, level 3, aggravated [1410]",0,0                                                                 |[Amherst,  Nova Scotia,  municipal [12001], 2010, "Assault, level 3, aggravated [1410]", 0, 0]                                                                 |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,"Assault, level 2, weapon or bodily harm [1420]",17,172.45                                                |[Amherst,  Nova Scotia,  municipal [12001], 2010, "Assault, level 2, weapon or bodily harm [1420]", 17, 172.45]                                                |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,"Assault, level 1 [1430]",153,1552.04                                                                     |[Amherst,  Nova Scotia,  municipal [12001], 2010, "Assault, level 1 [1430]", 153, 1552.04]                                                                     |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,Total robbery [160],6,60.86                                                                               |[Amherst,  Nova Scotia,  municipal [12001], 2010, Total robbery [160], 6, 60.86]                                                                               |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,Total breaking and entering [210],58,588.35                                                               |[Amherst,  Nova Scotia,  municipal [12001], 2010, Total breaking and entering [210], 58, 588.35]                                                               |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,Total theft of motor vehicle [220],4,40.58                                                                |[Amherst,  Nova Scotia,  municipal [12001], 2010, Total theft of motor vehicle [220], 4, 40.58]                                                                |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,Total impaired driving [910],60,608.64                                                                    |[Amherst,  Nova Scotia,  municipal [12001], 2010, Total impaired driving [910], 60, 608.64]                                                                    |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,Total Drug violations [401],74,750.66                                                                     |[Amherst,  Nova Scotia,  municipal [12001], 2010, Total Drug violations [401], 74, 750.66]                                                                     |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,"Possession, cocaine [4120]",1,10.14                                                                      |[Amherst,  Nova Scotia,  municipal [12001], 2010, "Possession, cocaine [4120]", 1, 10.14]                                                                      |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,"Total, possession, other Controlled Drugs and Substances Act drugs [410]",0,0                            |[Amherst,  Nova Scotia,  municipal [12001], 2010, "Total, possession, other Controlled Drugs and Substances Act drugs [410]", 0, 0]                            |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,"Total cannabis, trafficking, production or distribution (pre-legalization) [420]",6,60.86                |[Amherst,  Nova Scotia,  municipal [12001], 2010, "Total cannabis, trafficking, production or distribution (pre-legalization) [420]", 6, 60.86]                |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,"Total cocaine, trafficking, production or distribution [430]",7,71.01                                    |[Amherst,  Nova Scotia,  municipal [12001], 2010, "Total cocaine, trafficking, production or distribution [430]", 7, 71.01]                                    |7       |
# |Amherst, Nova Scotia, municipal [12001],2010,"Total other Controlled Drugs and Substances Act drugs, trafficking, production or distribution [440]",0,0|[Amherst,  Nova Scotia,  municipal [12001], 2010, "Total other Controlled Drugs and Substances Act drugs, trafficking, production or distribution [440]", 0, 0]|7       |
# |Annapolis Royal, Nova Scotia, municipal [12002],2010,Homicide [110],0,0                                                                                |[Annapolis Royal,  Nova Scotia,  municipal [12002], 2010, Homicide [110], 0, 0]                                                                                |7       |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
# only showing top 20 rows
#
# +----------------+----+-------------------------------------------------------+---------+-----+
# |Geography       |Year|Violations                                             |Incidents|Rates|
# +----------------+----+-------------------------------------------------------+---------+-----+
# |Nova Scotia [12]|2010|Homicide [110]                                         |21       |2.23 |
# |Nova Scotia [12]|2010|Attempted murder [1210]                                |24       |2.55 |
# |Nova Scotia [12]|2010|"Sexual assault, level 3, aggravated [1310]"           |6        |0.64 |
# |Nova Scotia [12]|2010|"Sexual assault, level 2, weapon or bodily harm [1320]"|13       |1.38 |
# |Nova Scotia [12]|2010|"Sexual assault, level 1 [1330]"                       |662      |70.27|
# +----------------+----+-------------------------------------------------------+---------+-----+
# only showing top 5 rows
#
# +-----------------------------------------+----+-------------------------------------------------------+---------+-----+
# |Geography                                |Year|Violations                                             |Incidents|Rates|
# +-----------------------------------------+----+-------------------------------------------------------+---------+-----+
# |Amherst,  Nova Scotia,  municipal [12001]|2010|Homicide [110]                                         |1        |10.14|
# |Amherst,  Nova Scotia,  municipal [12001]|2010|Attempted murder [1210]                                |0        |0    |
# |Amherst,  Nova Scotia,  municipal [12001]|2010|"Sexual assault, level 3, aggravated [1310]"           |0        |0    |
# |Amherst,  Nova Scotia,  municipal [12001]|2010|"Sexual assault, level 2, weapon or bodily harm [1320]"|0        |0    |
# |Amherst,  Nova Scotia,  municipal [12001]|2010|"Sexual assault, level 1 [1330]"                       |8        |81.15|
# +-----------------------------------------+----+-------------------------------------------------------+---------+-----+
# only showing top 5 rows
#
# root
#  |-- Geography: string (nullable = true)
#  |-- Year: string (nullable = true)
#  |-- Violations: string (nullable = true)
#  |-- Incidents: string (nullable = true)
#  |-- Rates: string (nullable = true)
#
# +----------------+----+------------------------------------------------------------------------------------------------------+---------+------+
# |Geography       |Year|Violations                                                                                            |Incidents|Rates |
# +----------------+----+------------------------------------------------------------------------------------------------------+---------+------+
# |Nova Scotia [12]|2010|Homicide [110]                                                                                        |21       |2.23  |
# |Nova Scotia [12]|2010|Attempted murder [1210]                                                                               |24       |2.55  |
# |Nova Scotia [12]|2010|"Sexual assault, level 3, aggravated [1310]"                                                          |6        |0.64  |
# |Nova Scotia [12]|2010|"Sexual assault, level 2, weapon or bodily harm [1320]"                                               |13       |1.38  |
# |Nova Scotia [12]|2010|"Sexual assault, level 1 [1330]"                                                                      |662      |70.27 |
# |Nova Scotia [12]|2010|Total sexual violations against children [130]                                                        |93       |9.87  |
# |Nova Scotia [12]|2010|"Assault, level 3, aggravated [1410]"                                                                 |85       |9.02  |
# |Nova Scotia [12]|2010|"Assault, level 2, weapon or bodily harm [1420]"                                                      |1212     |128.65|
# |Nova Scotia [12]|2010|"Assault, level 1 [1430]"                                                                             |5780     |613.54|
# |Nova Scotia [12]|2010|Total robbery [160]                                                                                   |490      |52.01 |
# |Nova Scotia [12]|2010|Total breaking and entering [210]                                                                     |5269     |559.3 |
# |Nova Scotia [12]|2010|Total theft of motor vehicle [220]                                                                    |1281     |135.98|
# |Nova Scotia [12]|2010|Total impaired driving [910]                                                                          |3431     |364.2 |
# |Nova Scotia [12]|2010|Total Drug violations [401]                                                                           |3136     |332.88|
# |Nova Scotia [12]|2010|"Possession, cocaine [4120]"                                                                          |126      |13.37 |
# |Nova Scotia [12]|2010|"Total, possession, other Controlled Drugs and Substances Act drugs [410]"                            |214      |22.72 |
# |Nova Scotia [12]|2010|"Total cannabis, trafficking, production or distribution (pre-legalization) [420]"                    |727      |77.17 |
# |Nova Scotia [12]|2010|"Total cocaine, trafficking, production or distribution [430]"                                        |191      |20.27 |
# |Nova Scotia [12]|2010|"Total other Controlled Drugs and Substances Act drugs, trafficking, production or distribution [440]"|228      |24.2  |
# |Nova Scotia [12]|2011|Homicide [110]                                                                                        |22       |2.33  |
# |Nova Scotia [12]|2011|Attempted murder [1210]                                                                               |60       |6.35  |
# |Nova Scotia [12]|2011|"Sexual assault, level 3, aggravated [1310]"                                                          |8        |0.85  |
# |Nova Scotia [12]|2011|"Sexual assault, level 2, weapon or bodily harm [1320]"                                               |6        |0.64  |
# |Nova Scotia [12]|2011|"Sexual assault, level 1 [1330]"                                                                      |686      |72.65 |
# |Nova Scotia [12]|2011|Total sexual violations against children [130]                                                        |108      |11.44 |
# |Nova Scotia [12]|2011|"Assault, level 3, aggravated [1410]"                                                                 |91       |9.64  |
# |Nova Scotia [12]|2011|"Assault, level 2, weapon or bodily harm [1420]"                                                      |1412     |149.53|
# |Nova Scotia [12]|2011|"Assault, level 1 [1430]"                                                                             |5567     |589.55|
# |Nova Scotia [12]|2011|Total robbery [160]                                                                                   |469      |49.67 |
# |Nova Scotia [12]|2011|Total breaking and entering [210]                                                                     |4769     |505.04|
# |Nova Scotia [12]|2011|Total theft of motor vehicle [220]                                                                    |1299     |137.57|
# |Nova Scotia [12]|2011|Total impaired driving [910]                                                                          |3095     |327.77|
# |Nova Scotia [12]|2011|Total Drug violations [401]                                                                           |3273     |346.62|
# |Nova Scotia [12]|2011|"Possession, cocaine [4120]"                                                                          |126      |13.34 |
# |Nova Scotia [12]|2011|"Total, possession, other Controlled Drugs and Substances Act drugs [410]"                            |220      |23.3  |
# |Nova Scotia [12]|2011|"Total cannabis, trafficking, production or distribution (pre-legalization) [420]"                    |679      |71.91 |
# |Nova Scotia [12]|2011|"Total cocaine, trafficking, production or distribution [430]"                                        |221      |23.4  |
# |Nova Scotia [12]|2011|"Total other Controlled Drugs and Substances Act drugs, trafficking, production or distribution [440]"|231      |24.46 |
# |Nova Scotia [12]|2012|Homicide [110]                                                                                        |17       |1.8   |
# |Nova Scotia [12]|2012|Attempted murder [1210]                                                                               |34       |3.6   |
# |Nova Scotia [12]|2012|"Sexual assault, level 3, aggravated [1310]"                                                          |5        |0.53  |
# |Nova Scotia [12]|2012|"Sexual assault, level 2, weapon or bodily harm [1320]"                                               |9        |0.95  |
# |Nova Scotia [12]|2012|"Sexual assault, level 1 [1330]"                                                                      |659      |69.84 |
# |Nova Scotia [12]|2012|Total sexual violations against children [130]                                                        |72       |7.63  |
# |Nova Scotia [12]|2012|"Assault, level 3, aggravated [1410]"                                                                 |69       |7.31  |
# |Nova Scotia [12]|2012|"Assault, level 2, weapon or bodily harm [1420]"                                                      |1390     |147.3 |
# |Nova Scotia [12]|2012|"Assault, level 1 [1430]"                                                                             |5284     |559.96|
# |Nova Scotia [12]|2012|Total robbery [160]                                                                                   |443      |46.95 |
# |Nova Scotia [12]|2012|Total breaking and entering [210]                                                                     |4829     |511.74|
# |Nova Scotia [12]|2012|Total theft of motor vehicle [220]                                                                    |1326     |140.52|
# +----------------+----+------------------------------------------------------------------------------------------------------+---------+------+
# only showing top 50 rows
#
# +----------------------------------------------------------------+
# |Geography                                                       |
# +----------------------------------------------------------------+
# |Nova Scotia [12]                                                |
# |Lunenburg County,  Nova Scotia,  Royal Canadian Mounted Police  |
# |Chester,  Nova Scotia,  Royal Canadian Mounted Police           |
# |Halifax County,  Nova Scotia,  Royal Canadian Mounted Police    |
# |Sheet Harbour,  Nova Scotia,  Royal Canadian Mounted Police     |
# |Digby,  Nova Scotia,  municipal [12012]                         |
# |Halifax Metropolitan Area,  Nova Scotia,  municipal [12099]     |
# |Kentville,  Nova Scotia,  municipal [12023]                     |
# |Yarmouth,  Nova Scotia,  municipal [12057]                      |
# |Lunenburg,  Nova Scotia,  Royal Canadian Mounted Police         |
# |Wolfville,  Nova Scotia,  municipal [12056]                     |
# |Meteghan (Clare),  Nova Scotia,  Royal Canadian Mounted Police  |
# |Richmond County,  Nova Scotia,  Royal Canadian Mounted Police   |
# |Queens County,  Nova Scotia,  Royal Canadian Mounted Police     |
# |Cape Breton,  Nova Scotia,  Royal Canadian Mounted Police       |
# |Amherst,  Nova Scotia,  municipal [12001]                       |
# |Kings County,  Nova Scotia,  Royal Canadian Mounted Police      |
# |Westville,  Nova Scotia,  municipal [12054]                     |
# |Barrington,  Nova Scotia,  Royal Canadian Mounted Police        |
# |Clark's Harbour,  Nova Scotia,  municipal [12008]               |
# |Trenton,  Nova Scotia,  municipal [12059]                       |
# |Annapolis Royal,  Nova Scotia,  municipal [12002]               |
# |Stellarton,  Nova Scotia,  municipal [12044]                    |
# |Hantsport,  Nova Scotia,  municipal [12021]                     |
# |Colchester County,  Nova Scotia,  Royal Canadian Mounted Police |
# |Tantallon,  Nova Scotia,  Royal Canadian Mounted Police         |
# |Cole Harbour,  Nova Scotia,  Royal Canadian Mounted Police      |
# |Eskasoni,  Nova Scotia,  Royal Canadian Mounted Police          |
# |Berwick,  Nova Scotia,  municipal [12004]                       |
# |Parrsboro,  Nova Scotia,  Royal Canadian Mounted Police         |
# |Halifax (offshore),  Nova Scotia,  Royal Canadian Mounted Police|
# |Middleton,  Nova Scotia,  municipal [12031]                     |
# |North Sydney,  Nova Scotia,  municipal [12035]                  |
# |Halifax,  Nova Scotia,  municipal [12020]                       |
# |Eskasoni,  Nova Scotia,  municipal [12065]                      |
# |Pictou County,  Nova Scotia,  Royal Canadian Mounted Police     |
# |Bridgewater,  Nova Scotia,  municipal [12006]                   |
# |Cape Breton Region,  Nova Scotia,  municipal [12018]            |
# |Sydney,  Nova Scotia,  municipal [12048]                        |
# |Truro,  Nova Scotia,  municipal [12052]                         |
# |Glace Bay,  Nova Scotia,  municipal [12014]                     |
# |West Hants,  Nova Scotia,  Royal Canadian Mounted Police        |
# |Lunenburg,  Nova Scotia,  municipal [12029]                     |
# |Windsor,  Nova Scotia,  Royal Canadian Mounted Police           |
# |Membertou,  Nova Scotia,  Royal Canadian Mounted Police         |
# |Digby,  Nova Scotia,  Royal Canadian Mounted Police             |
# |Annapolis County,  Nova Scotia,  Royal Canadian Mounted Police  |
# |Springhill,  Nova Scotia,  municipal [12043]                    |
# |New Glasgow Region,  Nova Scotia,  municipal [12058]            |
# |Lower Sackville,  Nova Scotia,  Royal Canadian Mounted Police   |
# +----------------------------------------------------------------+
# only showing top 50 rows
#
# +----------------+----+--------------------+---------+------+
# |       Geography|Year|          Violations|Incidents| Rates|
# +----------------+----+--------------------+---------+------+
# |Nova Scotia [12]|2010|      Homicide [110]|       21|  2.23|
# |Nova Scotia [12]|2010|Attempted murder ...|       24|  2.55|
# |Nova Scotia [12]|2010|"Sexual assault, ...|        6|  0.64|
# |Nova Scotia [12]|2010|"Sexual assault, ...|       13|  1.38|
# |Nova Scotia [12]|2010|"Sexual assault, ...|      662| 70.27|
# |Nova Scotia [12]|2010|Total sexual viol...|       93|  9.87|
# |Nova Scotia [12]|2010|"Assault, level 3...|       85|  9.02|
# |Nova Scotia [12]|2010|"Assault, level 2...|     1212|128.65|
# |Nova Scotia [12]|2010|"Assault, level 1...|     5780|613.54|
# |Nova Scotia [12]|2010| Total robbery [160]|      490| 52.01|
# |Nova Scotia [12]|2010|Total breaking an...|     5269| 559.3|
# |Nova Scotia [12]|2010|Total theft of mo...|     1281|135.98|
# |Nova Scotia [12]|2010|Total impaired dr...|     3431| 364.2|
# |Nova Scotia [12]|2010|Total Drug violat...|     3136|332.88|
# |Nova Scotia [12]|2010|"Possession, coca...|      126| 13.37|
# |Nova Scotia [12]|2010|"Total, possessio...|      214| 22.72|
# |Nova Scotia [12]|2010|"Total cannabis, ...|      727| 77.17|
# |Nova Scotia [12]|2010|"Total cocaine, t...|      191| 20.27|
# |Nova Scotia [12]|2010|"Total other Cont...|      228|  24.2|
# |Nova Scotia [12]|2011|      Homicide [110]|       22|  2.33|
# |Nova Scotia [12]|2011|Attempted murder ...|       60|  6.35|
# |Nova Scotia [12]|2011|"Sexual assault, ...|        8|  0.85|
# |Nova Scotia [12]|2011|"Sexual assault, ...|        6|  0.64|
# |Nova Scotia [12]|2011|"Sexual assault, ...|      686| 72.65|
# |Nova Scotia [12]|2011|Total sexual viol...|      108| 11.44|
# |Nova Scotia [12]|2011|"Assault, level 3...|       91|  9.64|
# |Nova Scotia [12]|2011|"Assault, level 2...|     1412|149.53|
# |Nova Scotia [12]|2011|"Assault, level 1...|     5567|589.55|
# |Nova Scotia [12]|2011| Total robbery [160]|      469| 49.67|
# |Nova Scotia [12]|2011|Total breaking an...|     4769|505.04|
# |Nova Scotia [12]|2011|Total theft of mo...|     1299|137.57|
# |Nova Scotia [12]|2011|Total impaired dr...|     3095|327.77|
# |Nova Scotia [12]|2011|Total Drug violat...|     3273|346.62|
# |Nova Scotia [12]|2011|"Possession, coca...|      126| 13.34|
# |Nova Scotia [12]|2011|"Total, possessio...|      220|  23.3|
# |Nova Scotia [12]|2011|"Total cannabis, ...|      679| 71.91|
# |Nova Scotia [12]|2011|"Total cocaine, t...|      221|  23.4|
# |Nova Scotia [12]|2011|"Total other Cont...|      231| 24.46|
# |Nova Scotia [12]|2012|      Homicide [110]|       17|   1.8|
# |Nova Scotia [12]|2012|Attempted murder ...|       34|   3.6|
# |Nova Scotia [12]|2012|"Sexual assault, ...|        5|  0.53|
# |Nova Scotia [12]|2012|"Sexual assault, ...|        9|  0.95|
# |Nova Scotia [12]|2012|"Sexual assault, ...|      659| 69.84|
# |Nova Scotia [12]|2012|Total sexual viol...|       72|  7.63|
# |Nova Scotia [12]|2012|"Assault, level 3...|       69|  7.31|
# |Nova Scotia [12]|2012|"Assault, level 2...|     1390| 147.3|
# |Nova Scotia [12]|2012|"Assault, level 1...|     5284|559.96|
# |Nova Scotia [12]|2012| Total robbery [160]|      443| 46.95|
# |Nova Scotia [12]|2012|Total breaking an...|     4829|511.74|
# |Nova Scotia [12]|2012|Total theft of mo...|     1326|140.52|
# +----------------+----+--------------------+---------+------+
# only showing top 50 rows

# %%
# Filtrar filas donde Year sea un número válido (año) y Violations sea texto
from pyspark.sql.functions import col, regexp_replace

# Filtrar registros válidos para Year
df_clean = df_final.filter(col("Year").rlike("^[0-9]{4}$"))

# Eliminar espacios y comillas de la columna Year y asegurarse de que Year es numérica
df_clean = df_clean.withColumn("Year", regexp_replace(col("Year"), '"', '').cast("int"))

df_clean.show()
# Out:
# +----------------+----+--------------------+---------+------+
# |       Geography|Year|          Violations|Incidents| Rates|
# +----------------+----+--------------------+---------+------+
# |Nova Scotia [12]|2010|      Homicide [110]|       21|  2.23|
# |Nova Scotia [12]|2010|Attempted murder ...|       24|  2.55|
# |Nova Scotia [12]|2010|"Sexual assault, ...|        6|  0.64|
# |Nova Scotia [12]|2010|"Sexual assault, ...|       13|  1.38|
# |Nova Scotia [12]|2010|"Sexual assault, ...|      662| 70.27|
# |Nova Scotia [12]|2010|Total sexual viol...|       93|  9.87|
# |Nova Scotia [12]|2010|"Assault, level 3...|       85|  9.02|
# |Nova Scotia [12]|2010|"Assault, level 2...|     1212|128.65|
# |Nova Scotia [12]|2010|"Assault, level 1...|     5780|613.54|
# |Nova Scotia [12]|2010| Total robbery [160]|      490| 52.01|
# |Nova Scotia [12]|2010|Total breaking an...|     5269| 559.3|
# |Nova Scotia [12]|2010|Total theft of mo...|     1281|135.98|
# |Nova Scotia [12]|2010|Total impaired dr...|     3431| 364.2|
# |Nova Scotia [12]|2010|Total Drug violat...|     3136|332.88|
# |Nova Scotia [12]|2010|"Possession, coca...|      126| 13.37|
# |Nova Scotia [12]|2010|"Total, possessio...|      214| 22.72|
# |Nova Scotia [12]|2010|"Total cannabis, ...|      727| 77.17|
# |Nova Scotia [12]|2010|"Total cocaine, t...|      191| 20.27|
# |Nova Scotia [12]|2010|"Total other Cont...|      228|  24.2|
# |Nova Scotia [12]|2011|      Homicide [110]|       22|  2.33|
# +----------------+----+--------------------+---------+------+
# only showing top 20 rows

# %%
# Filtrar registros válidos para Violations (no deben ser solo números)
df_clean = df_clean.filter(~col("Violations").rlike("^[0-9]+$"))

# Asegurarse de que la columna Violations no tenga valores erróneos como años
df_clean = df_clean.withColumn("Violations", regexp_replace(col("Violations"), '"', '').cast("string"))

df_clean.show()
# Out:
# +----------------+----+--------------------+---------+------+
# |       Geography|Year|          Violations|Incidents| Rates|
# +----------------+----+--------------------+---------+------+
# |Nova Scotia [12]|2010|      Homicide [110]|       21|  2.23|
# |Nova Scotia [12]|2010|Attempted murder ...|       24|  2.55|
# |Nova Scotia [12]|2010|Sexual assault, l...|        6|  0.64|
# |Nova Scotia [12]|2010|Sexual assault, l...|       13|  1.38|
# |Nova Scotia [12]|2010|Sexual assault, l...|      662| 70.27|
# |Nova Scotia [12]|2010|Total sexual viol...|       93|  9.87|
# |Nova Scotia [12]|2010|Assault, level 3,...|       85|  9.02|
# |Nova Scotia [12]|2010|Assault, level 2,...|     1212|128.65|
# |Nova Scotia [12]|2010|Assault, level 1 ...|     5780|613.54|
# |Nova Scotia [12]|2010| Total robbery [160]|      490| 52.01|
# |Nova Scotia [12]|2010|Total breaking an...|     5269| 559.3|
# |Nova Scotia [12]|2010|Total theft of mo...|     1281|135.98|
# |Nova Scotia [12]|2010|Total impaired dr...|     3431| 364.2|
# |Nova Scotia [12]|2010|Total Drug violat...|     3136|332.88|
# |Nova Scotia [12]|2010|Possession, cocai...|      126| 13.37|
# |Nova Scotia [12]|2010|Total, possession...|      214| 22.72|
# |Nova Scotia [12]|2010|Total cannabis, t...|      727| 77.17|
# |Nova Scotia [12]|2010|Total cocaine, tr...|      191| 20.27|
# |Nova Scotia [12]|2010|Total other Contr...|      228|  24.2|
# |Nova Scotia [12]|2011|      Homicide [110]|       22|  2.33|
# +----------------+----+--------------------+---------+------+
# only showing top 20 rows

# %%
# Verificar los valores únicos en Year y Violations después de la limpieza
df_clean.select("Year").distinct().orderBy("Year").show()
df_clean.select("Violations").distinct().orderBy("Violations").show()
# Out:
# +----+
# |Year|
# +----+
# |2010|
# |2011|
# |2012|
# |2013|
# |2014|
# |2015|
# |2016|
# |2017|
# |2018|
# |2019|
# |2020|
# |2021|
# |2022|
# +----+
#
# +--------------------+
# |          Violations|
# +--------------------+
# |Assault, level 1 ...|
# |Assault, level 2,...|
# |Assault, level 3,...|
# |Attempted murder ...|
# |      Homicide [110]|
# |Possession, cocai...|
# |Sexual assault, l...|
# |Sexual assault, l...|
# |Sexual assault, l...|
# |Total Drug violat...|
# |Total breaking an...|
# |Total cannabis, t...|
# |Total cocaine, tr...|
# |Total impaired dr...|
# |Total other Contr...|
# | Total robbery [160]|
# |Total sexual viol...|
# |Total theft of mo...|
# |Total, possession...|
# +--------------------+

# %%
# Mostrar los valores únicos de Geography para verificar que están completos
df_final.select("Geography").distinct().show(50, truncate=False)
# Out:
# +----------------------------------------------------------------+
# |Geography                                                       |
# +----------------------------------------------------------------+
# |Nova Scotia [12]                                                |
# |Lunenburg County,  Nova Scotia,  Royal Canadian Mounted Police  |
# |Chester,  Nova Scotia,  Royal Canadian Mounted Police           |
# |Halifax County,  Nova Scotia,  Royal Canadian Mounted Police    |
# |Sheet Harbour,  Nova Scotia,  Royal Canadian Mounted Police     |
# |Digby,  Nova Scotia,  municipal [12012]                         |
# |Halifax Metropolitan Area,  Nova Scotia,  municipal [12099]     |
# |Kentville,  Nova Scotia,  municipal [12023]                     |
# |Yarmouth,  Nova Scotia,  municipal [12057]                      |
# |Lunenburg,  Nova Scotia,  Royal Canadian Mounted Police         |
# |Wolfville,  Nova Scotia,  municipal [12056]                     |
# |Meteghan (Clare),  Nova Scotia,  Royal Canadian Mounted Police  |
# |Richmond County,  Nova Scotia,  Royal Canadian Mounted Police   |
# |Queens County,  Nova Scotia,  Royal Canadian Mounted Police     |
# |Cape Breton,  Nova Scotia,  Royal Canadian Mounted Police       |
# |Amherst,  Nova Scotia,  municipal [12001]                       |
# |Kings County,  Nova Scotia,  Royal Canadian Mounted Police      |
# |Westville,  Nova Scotia,  municipal [12054]                     |
# |Barrington,  Nova Scotia,  Royal Canadian Mounted Police        |
# |Clark's Harbour,  Nova Scotia,  municipal [12008]               |
# |Trenton,  Nova Scotia,  municipal [12059]                       |
# |Annapolis Royal,  Nova Scotia,  municipal [12002]               |
# |Stellarton,  Nova Scotia,  municipal [12044]                    |
# |Hantsport,  Nova Scotia,  municipal [12021]                     |
# |Colchester County,  Nova Scotia,  Royal Canadian Mounted Police |
# |Tantallon,  Nova Scotia,  Royal Canadian Mounted Police         |
# |Cole Harbour,  Nova Scotia,  Royal Canadian Mounted Police      |
# |Eskasoni,  Nova Scotia,  Royal Canadian Mounted Police          |
# |Berwick,  Nova Scotia,  municipal [12004]                       |
# |Parrsboro,  Nova Scotia,  Royal Canadian Mounted Police         |
# |Halifax (offshore),  Nova Scotia,  Royal Canadian Mounted Police|
# |Middleton,  Nova Scotia,  municipal [12031]                     |
# |North Sydney,  Nova Scotia,  municipal [12035]                  |
# |Halifax,  Nova Scotia,  municipal [12020]                       |
# |Eskasoni,  Nova Scotia,  municipal [12065]                      |
# |Pictou County,  Nova Scotia,  Royal Canadian Mounted Police     |
# |Bridgewater,  Nova Scotia,  municipal [12006]                   |
# |Cape Breton Region,  Nova Scotia,  municipal [12018]            |
# |Sydney,  Nova Scotia,  municipal [12048]                        |
# |Truro,  Nova Scotia,  municipal [12052]                         |
# |Glace Bay,  Nova Scotia,  municipal [12014]                     |
# |West Hants,  Nova Scotia,  Royal Canadian Mounted Police        |
# |Lunenburg,  Nova Scotia,  municipal [12029]                     |
# |Windsor,  Nova Scotia,  Royal Canadian Mounted Police           |
# |Membertou,  Nova Scotia,  Royal Canadian Mounted Police         |
# |Digby,  Nova Scotia,  Royal Canadian Mounted Police             |
# |Annapolis County,  Nova Scotia,  Royal Canadian Mounted Police  |
# |Springhill,  Nova Scotia,  municipal [12043]                    |
# |New Glasgow Region,  Nova Scotia,  municipal [12058]            |
# |Lower Sackville,  Nova Scotia,  Royal Canadian Mounted Police   |
# +----------------------------------------------------------------+
# only showing top 50 rows

# %%
# Asumiendo que los nombres de las columnas en la fila incorrecta están en mayúsculas
df_final = df_final.filter(df_final.Geography != "Geography")

# Verificar que la fila fue eliminada correctamente
df_final.show(5, truncate=False)
# Out:
# +----------------+----+-------------------------------------------------------+---------+-----+
# |Geography       |Year|Violations                                             |Incidents|Rates|
# +----------------+----+-------------------------------------------------------+---------+-----+
# |Nova Scotia [12]|2010|Homicide [110]                                         |21       |2.23 |
# |Nova Scotia [12]|2010|Attempted murder [1210]                                |24       |2.55 |
# |Nova Scotia [12]|2010|"Sexual assault, level 3, aggravated [1310]"           |6        |0.64 |
# |Nova Scotia [12]|2010|"Sexual assault, level 2, weapon or bodily harm [1320]"|13       |1.38 |
# |Nova Scotia [12]|2010|"Sexual assault, level 1 [1330]"                       |662      |70.27|
# +----------------+----+-------------------------------------------------------+---------+-----+
# only showing top 5 rows

# %% [markdown]
# file_path = 'dbfs:/FileStore/tables/crime_statistics_-_incidents_and_rates_for_selected_offences.csv/'

# %%
# Mostrar los valores únicos en la columna 'Incidents' para identificar posibles problemas
df_final.select("Incidents").distinct().show(100, truncate=False)
# Out:
# +---------+
# |Incidents|
# +---------+
# |1412     |
# |727      |
# |686      |
# |8        |
# |22       |
# |3095     |
# |85       |
# |4769     |
# |214      |
# |221      |
# |126      |
# |228      |
# |6        |
# |60       |
# |220      |
# |93       |
# |3273     |
# |3431     |
# |231      |
# |108      |
# |5780     |
# |679      |
# |1212     |
# |490      |
# |24       |
# |1281     |
# |1299     |
# |13       |
# |191      |
# |21       |
# |662      |
# |91       |
# |3136     |
# |469      |
# |5269     |
# |5567     |
# |69       |
# |34       |
# |443      |
# |4829     |
# |4608     |
# |609      |
# |5        |
# |61       |
# |659      |
# |17       |
# |131      |
# |640      |
# |3197     |
# |136      |
# |2899     |
# |292      |
# |1326     |
# |193      |
# |122      |
# |2715     |
# |4091     |
# |1390     |
# |217      |
# |3071     |
# |9        |
# |624      |
# |5284     |
# |222      |
# |4        |
# |249      |
# |1118     |
# |1083     |
# |72       |
# |337      |
# |216      |
# |574      |
# |138      |
# |3        |
# |133      |
# |2862     |
# |610      |
# |1082     |
# |3689     |
# |280      |
# |247      |
# |4581     |
# |212      |
# |3168     |
# |1075     |
# |2        |
# |57       |
# |3210     |
# |7        |
# |282      |
# |652      |
# |2758     |
# |203      |
# |28       |
# |2660     |
# |219      |
# |2794     |
# |1053     |
# |89       |
# |198      |
# +---------+
# only showing top 100 rows

# %%
from pyspark.sql.types import StructType, StructField, StringType

# Definir un esquema inicial con todas las columnas como StringType
schema = StructType([
    StructField("Geography", StringType(), True),
    StructField("Year", StringType(), True),
    StructField("Violations", StringType(), True),
    StructField("Incidents", StringType(), True),
    StructField("Rates", StringType(), True)
])

# Cargar el DataFrame con el esquema StringType para evitar problemas de conversión inmediata
df_final = spark.createDataFrame(df_final.rdd, schema)

# Mostrar las primeras filas para verificar el contenido
df_final.show(10, truncate=False)
df_final.printSchema()
# Out:
# +----------------+----+-------------------------------------------------------+---------+------+
# |Geography       |Year|Violations                                             |Incidents|Rates |
# +----------------+----+-------------------------------------------------------+---------+------+
# |Nova Scotia [12]|2010|Homicide [110]                                         |21       |2.23  |
# |Nova Scotia [12]|2010|Attempted murder [1210]                                |24       |2.55  |
# |Nova Scotia [12]|2010|"Sexual assault, level 3, aggravated [1310]"           |6        |0.64  |
# |Nova Scotia [12]|2010|"Sexual assault, level 2, weapon or bodily harm [1320]"|13       |1.38  |
# |Nova Scotia [12]|2010|"Sexual assault, level 1 [1330]"                       |662      |70.27 |
# |Nova Scotia [12]|2010|Total sexual violations against children [130]         |93       |9.87  |
# |Nova Scotia [12]|2010|"Assault, level 3, aggravated [1410]"                  |85       |9.02  |
# |Nova Scotia [12]|2010|"Assault, level 2, weapon or bodily harm [1420]"       |1212     |128.65|
# |Nova Scotia [12]|2010|"Assault, level 1 [1430]"                              |5780     |613.54|
# |Nova Scotia [12]|2010|Total robbery [160]                                    |490      |52.01 |
# +----------------+----+-------------------------------------------------------+---------+------+
# only showing top 10 rows
#
# root
#  |-- Geography: string (nullable = true)
#  |-- Year: string (nullable = true)
#  |-- Violations: string (nullable = true)
#  |-- Incidents: string (nullable = true)
#  |-- Rates: string (nullable = true)

# %%
from pyspark.sql.types import IntegerType, DoubleType

# Convertir las columnas con tipos de datos correctos
df_clean = df_clean.withColumn("Incidents", col("Incidents").cast(IntegerType())) \
                   .withColumn("Rates", col("Rates").cast(DoubleType()))

# Verificar nuevamente el esquema y los datos
df_clean.printSchema()
df_clean.show(10, truncate=False)
# Out:
# root
#  |-- Geography: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Violations: string (nullable = true)
#  |-- Incidents: integer (nullable = true)
#  |-- Rates: double (nullable = true)
#
# +----------------+----+-----------------------------------------------------+---------+------+
# |Geography       |Year|Violations                                           |Incidents|Rates |
# +----------------+----+-----------------------------------------------------+---------+------+
# |Nova Scotia [12]|2010|Homicide [110]                                       |21       |2.23  |
# |Nova Scotia [12]|2010|Attempted murder [1210]                              |24       |2.55  |
# |Nova Scotia [12]|2010|Sexual assault, level 3, aggravated [1310]           |6        |0.64  |
# |Nova Scotia [12]|2010|Sexual assault, level 2, weapon or bodily harm [1320]|13       |1.38  |
# |Nova Scotia [12]|2010|Sexual assault, level 1 [1330]                       |662      |70.27 |
# |Nova Scotia [12]|2010|Total sexual violations against children [130]       |93       |9.87  |
# |Nova Scotia [12]|2010|Assault, level 3, aggravated [1410]                  |85       |9.02  |
# |Nova Scotia [12]|2010|Assault, level 2, weapon or bodily harm [1420]       |1212     |128.65|
# |Nova Scotia [12]|2010|Assault, level 1 [1430]                              |5780     |613.54|
# |Nova Scotia [12]|2010|Total robbery [160]                                  |490      |52.01 |
# +----------------+----+-----------------------------------------------------+---------+------+
# only showing top 10 rows

# %%
# Crear la vista limpia para usar con SQL
df_clean.createOrReplaceTempView("clean_crime_data")

# Consulta SQL para contar incidentes por año y región
spark.sql("""
    SELECT Year, Geography, SUM(Incidents) as Total_Incidents
    FROM clean_crime_data
    GROUP BY Year, Geography
    ORDER BY Year, Geography
""").show(100, truncate=False)
# Out:
# +----+---------------------------------------------------------------------------------------+---------------+
# |Year|Geography                                                                              |Total_Incidents|
# +----+---------------------------------------------------------------------------------------+---------------+
# |2010|Amherst,  Nova Scotia,  municipal [12001]                                              |397            |
# |2010|Annapolis Royal,  Nova Scotia,  municipal [12002]                                      |18             |
# |2010|Berwick,  Nova Scotia,  municipal [12004]                                              |null           |
# |2010|Bridgewater,  Nova Scotia,  municipal [12006]                                          |255            |
# |2010|Cape Breton Region,  Nova Scotia,  municipal [12018]                                   |1885           |
# |2010|Clark's Harbour,  Nova Scotia,  municipal [12008]                                      |null           |
# |2010|Digby,  Nova Scotia,  municipal [12012]                                                |null           |
# |2010|Eskasoni,  Nova Scotia,  municipal [12065]                                             |null           |
# |2010|Glace Bay,  Nova Scotia,  municipal [12014]                                            |null           |
# |2010|Halifax (Division Headquarters 1),  Nova Scotia,  Royal Canadian Mounted Police [12959]|0              |
# |2010|Halifax (Division Headquarters 2),  Nova Scotia,  Royal Canadian Mounted Police [12970]|0              |
# |2010|Halifax Metropolitan Area,  Nova Scotia,  municipal [12099]                            |9838           |
# |2010|Halifax,  Nova Scotia,  municipal [12020]                                              |0              |
# |2010|Hantsport,  Nova Scotia,  municipal [12021]                                            |null           |
# |2010|Kentville,  Nova Scotia,  municipal [12023]                                            |194            |
# |2010|Lunenburg,  Nova Scotia,  municipal [12029]                                            |null           |
# |2010|Middleton,  Nova Scotia,  municipal [12031]                                            |null           |
# |2010|New Glasgow Region,  Nova Scotia,  municipal [12058]                                   |442            |
# |2010|North Sydney,  Nova Scotia,  municipal [12035]                                         |null           |
# |2010|Nova Scotia [12]                                                                       |22989          |
# |2010|Port of Halifax,  Nova Scotia,  Ports Canada Police [12980]                            |null           |
# |2010|Springhill,  Nova Scotia,  municipal [12043]                                           |146            |
# |2010|Stellarton,  Nova Scotia,  municipal [12044]                                           |70             |
# |2010|Sydney,  Nova Scotia,  municipal [12048]                                               |null           |
# |2010|Trenton,  Nova Scotia,  municipal [12059]                                              |16             |
# |2010|Truro,  Nova Scotia,  municipal [12052]                                                |452            |
# |2010|Westville,  Nova Scotia,  municipal [12054]                                            |63             |
# |2010|Wolfville,  Nova Scotia,  municipal [12056]                                            |null           |
# |2010|Yarmouth,  Nova Scotia,  municipal [12057]                                             |null           |
# |2011|Amherst,  Nova Scotia,  municipal [12001]                                              |330            |
# |2011|Annapolis Royal,  Nova Scotia,  municipal [12002]                                      |25             |
# |2011|Berwick,  Nova Scotia,  municipal [12004]                                              |null           |
# |2011|Bridgewater,  Nova Scotia,  municipal [12006]                                          |285            |
# |2011|Cape Breton Region,  Nova Scotia,  municipal [12018]                                   |1819           |
# |2011|Clark's Harbour,  Nova Scotia,  municipal [12008]                                      |null           |
# |2011|Digby,  Nova Scotia,  municipal [12012]                                                |null           |
# |2011|Eskasoni,  Nova Scotia,  municipal [12065]                                             |null           |
# |2011|Glace Bay,  Nova Scotia,  municipal [12014]                                            |null           |
# |2011|Halifax (Division Headquarters 1),  Nova Scotia,  Royal Canadian Mounted Police [12959]|0              |
# |2011|Halifax (Division Headquarters 2),  Nova Scotia,  Royal Canadian Mounted Police [12970]|0              |
# |2011|Halifax Metropolitan Area,  Nova Scotia,  municipal [12099]                            |9374           |
# |2011|Halifax,  Nova Scotia,  municipal [12020]                                              |null           |
# |2011|Hantsport,  Nova Scotia,  municipal [12021]                                            |null           |
# |2011|Kentville,  Nova Scotia,  municipal [12023]                                            |199            |
# |2011|Lunenburg,  Nova Scotia,  municipal [12029]                                            |null           |
# |2011|Middleton,  Nova Scotia,  municipal [12031]                                            |null           |
# |2011|New Glasgow Region,  Nova Scotia,  municipal [12058]                                   |380            |
# |2011|North Sydney,  Nova Scotia,  municipal [12035]                                         |null           |
# |2011|Nova Scotia [12]                                                                       |22342          |
# |2011|Port of Halifax,  Nova Scotia,  Ports Canada Police [12980]                            |null           |
# |2011|Springhill,  Nova Scotia,  municipal [12043]                                           |131            |
# |2011|Stellarton,  Nova Scotia,  municipal [12044]                                           |95             |
# |2011|Sydney,  Nova Scotia,  municipal [12048]                                               |null           |
# |2011|Trenton,  Nova Scotia,  municipal [12059]                                              |null           |
# |2011|Truro,  Nova Scotia,  municipal [12052]                                                |453            |
# |2011|Westville,  Nova Scotia,  municipal [12054]                                            |53             |
# |2011|Wolfville,  Nova Scotia,  municipal [12056]                                            |null           |
# |2011|Yarmouth,  Nova Scotia,  municipal [12057]                                             |null           |
# |2012|Amherst,  Nova Scotia,  municipal [12001]                                              |316            |
# |2012|Annapolis Royal,  Nova Scotia,  municipal [12002]                                      |12             |
# |2012|Berwick,  Nova Scotia,  municipal [12004]                                              |null           |
# |2012|Bridgewater,  Nova Scotia,  municipal [12006]                                          |216            |
# |2012|Cape Breton Region,  Nova Scotia,  municipal [12018]                                   |1980           |
# |2012|Clark's Harbour,  Nova Scotia,  municipal [12008]                                      |null           |
# |2012|Digby,  Nova Scotia,  municipal [12012]                                                |null           |
# |2012|Eskasoni,  Nova Scotia,  municipal [12065]                                             |null           |
# |2012|Glace Bay,  Nova Scotia,  municipal [12014]                                            |null           |
# |2012|Halifax (Division Headquarters 1),  Nova Scotia,  Royal Canadian Mounted Police [12959]|0              |
# |2012|Halifax (Division Headquarters 2),  Nova Scotia,  Royal Canadian Mounted Police [12970]|0              |
# |2012|Halifax Metropolitan Area,  Nova Scotia,  municipal [12099]                            |8305           |
# |2012|Halifax,  Nova Scotia,  municipal [12020]                                              |null           |
# |2012|Hantsport,  Nova Scotia,  municipal [12021]                                            |null           |
# |2012|Kentville,  Nova Scotia,  municipal [12023]                                            |259            |
# |2012|Lunenburg,  Nova Scotia,  municipal [12029]                                            |null           |
# |2012|Middleton,  Nova Scotia,  municipal [12031]                                            |null           |
# |2012|New Glasgow Region,  Nova Scotia,  municipal [12058]                                   |313            |
# |2012|North Sydney,  Nova Scotia,  municipal [12035]                                         |null           |
# |2012|Nova Scotia [12]                                                                       |21471          |
# |2012|Port of Halifax,  Nova Scotia,  Ports Canada Police [12980]                            |null           |
# |2012|Springhill,  Nova Scotia,  municipal [12043]                                           |124            |
# |2012|Stellarton,  Nova Scotia,  municipal [12044]                                           |108            |
# |2012|Sydney,  Nova Scotia,  municipal [12048]                                               |null           |
# |2012|Trenton,  Nova Scotia,  municipal [12059]                                              |null           |
# |2012|Truro,  Nova Scotia,  municipal [12052]                                                |384            |
# |2012|Westville,  Nova Scotia,  municipal [12054]                                            |83             |
# |2012|Wolfville,  Nova Scotia,  municipal [12056]                                            |null           |
# |2012|Yarmouth,  Nova Scotia,  municipal [12057]                                             |null           |
# |2013|Amherst,  Nova Scotia,  municipal [12001]                                              |317            |
# |2013|Annapolis Royal,  Nova Scotia,  municipal [12002]                                      |16             |
# |2013|Berwick,  Nova Scotia,  municipal [12004]                                              |null           |
# |2013|Bridgewater,  Nova Scotia,  municipal [12006]                                          |211            |
# |2013|Cape Breton Region,  Nova Scotia,  municipal [12018]                                   |1510           |
# |2013|Clark's Harbour,  Nova Scotia,  municipal [12008]                                      |null           |
# |2013|Digby,  Nova Scotia,  municipal [12012]                                                |null           |
# |2013|Eskasoni,  Nova Scotia,  municipal [12065]                                             |null           |
# |2013|Glace Bay,  Nova Scotia,  municipal [12014]                                            |null           |
# |2013|Halifax (Division Headquarters 1),  Nova Scotia,  Royal Canadian Mounted Police [12959]|0              |
# |2013|Halifax (Division Headquarters 2),  Nova Scotia,  Royal Canadian Mounted Police [12970]|0              |
# |2013|Halifax Metropolitan Area,  Nova Scotia,  municipal [12099]                            |7429           |
# |2013|Halifax,  Nova Scotia,  municipal [12020]                                              |null           |
# +----+---------------------------------------------------------------------------------------+---------------+
# only showing top 100 rows

# %%
# Consulta SQL para contar la frecuencia de violaciones
spark.sql("""
    SELECT Violations, COUNT(*) as Frequency
    FROM clean_crime_data
    GROUP BY Violations
    ORDER BY Frequency DESC
""").show(10, truncate=False)
# Out:
# +------------------------------------------------------------------------+---------+
# |Violations                                                              |Frequency|
# +------------------------------------------------------------------------+---------+
# |Assault, level 2, weapon or bodily harm [1420]                          |377      |
# |Sexual assault, level 2, weapon or bodily harm [1320]                   |377      |
# |Assault, level 1 [1430]                                                 |377      |
# |Sexual assault, level 1 [1330]                                          |377      |
# |Total impaired driving [910]                                            |377      |
# |Sexual assault, level 3, aggravated [1310]                              |377      |
# |Total breaking and entering [210]                                       |377      |
# |Possession, cocaine [4120]                                              |377      |
# |Total, possession, other Controlled Drugs and Substances Act drugs [410]|377      |
# |Total cocaine, trafficking, production or distribution [430]            |377      |
# +------------------------------------------------------------------------+---------+
# only showing top 10 rows

# %%
# Spark SQL
spark.sql("""
    SELECT Violations, AVG(Rates) as Avg_Rate
    FROM clean_crime_data
    GROUP BY Violations
    ORDER BY Avg_Rate DESC
""").show(10, truncate=False)
# Out:
# +--------------------------------------------------------------------------------+------------------+
# |Violations                                                                      |Avg_Rate          |
# +--------------------------------------------------------------------------------+------------------+
# |Assault, level 1 [1430]                                                         |738.5789285714286 |
# |Total breaking and entering [210]                                               |343.8455395683454 |
# |Total impaired driving [910]                                                    |316.63115107913666|
# |Total Drug violations [401]                                                     |249.00297872340425|
# |Assault, level 2, weapon or bodily harm [1420]                                  |143.5349645390071 |
# |Total theft of motor vehicle [220]                                              |109.22042253521127|
# |Sexual assault, level 1 [1330]                                                  |84.17585714285714 |
# |Total cannabis, trafficking, production or distribution (pre-legalization) [420]|43.207887323943666|
# |Total robbery [160]                                                             |29.80258741258741 |
# |Total cocaine, trafficking, production or distribution [430]                    |28.760839160839154|
# +--------------------------------------------------------------------------------+------------------+
# only showing top 10 rows

# %%
# Spark SQL
spark.sql("""
    SELECT Geography, SUM(Incidents) as Total_Incidents
    FROM clean_crime_data
    GROUP BY Geography
    ORDER BY Total_Incidents DESC
""").show(10, truncate=False)
# Out:
# +-----------------------------------------------------------+---------------+
# |Geography                                                  |Total_Incidents|
# +-----------------------------------------------------------+---------------+
# |Nova Scotia [12]                                           |242646         |
# |Halifax Metropolitan Area,  Nova Scotia,  municipal [12099]|95346          |
# |Cape Breton Region,  Nova Scotia,  municipal [12018]       |19004          |
# |New Glasgow Region,  Nova Scotia,  municipal [12058]       |4512           |
# |Truro,  Nova Scotia,  municipal [12052]                    |4209           |
# |Amherst,  Nova Scotia,  municipal [12001]                  |3970           |
# |Bridgewater,  Nova Scotia,  municipal [12006]              |2536           |
# |Kentville,  Nova Scotia,  municipal [12023]                |2197           |
# |Stellarton,  Nova Scotia,  municipal [12044]               |1078           |
# |Westville,  Nova Scotia,  municipal [12054]                |741            |
# +-----------------------------------------------------------+---------------+
# only showing top 10 rows
